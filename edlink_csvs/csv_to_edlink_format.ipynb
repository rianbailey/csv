# %%
#imports 
import pandas as pd
from datetime import datetime as dt
import numpy as np
import difflib as dif
import re
import os
import math

# %% [markdown]
# # Convert MP CSV to Edlink Format

# %%
# MindPrint csv specific
class_columns = ['class_1', 'class_2', 'class_3', 'class_4']

# %%
#edlink types
roles = ['student','district-administrator','administrator','teacher']

def format_fix (current_value, acceptable_values ):
    if current_value not in acceptable_values:
        matches = dif.get_close_matches(current_value, acceptable_values, n = 1, cutoff = 0.7)

        if(len(matches) > 0):
            replacement = matches[0]
            # print(current_value, "not found in acceptable matches, replacing with", replacement)
            return replacement
        else:
            print("No match found for", current_value, ", please edit the csv")

    return current_value

# %%
df = pd.read_csv("master_roster.csv")
df
# Out:
#    first_name   last_name    password                    email  \
# 0         Sam     Bobrick   org_admin     Bobrick@bayside.demo
# 1     Michael      Poryes   org_admin      Poryes@bayside.demo
# 2       Susan     Sherman   org_admin     Sherman@bayside.demo
# 3     Richard     Belding  site_admin     Belding@bayside.demo
# 4      Wesley      Lawler  site_admin      Lawler@bayside.demo
# ..        ...         ...         ...                      ...
# 68    Larissa       Swing     student       Swing@bayside.demo
# 69   Augustin  Carbonelle     student  Carbonelle@bayside.demo
# 70     Vivian        Shah     student        Shah@bayside.demo
# 71      David    Langhoff     student    Langhoff@bayside.demo
# 72     Declan     Brennan     student     Brennan@bayside.demo
#
#                       role  gender   birthdate  user_school_id  \
# 0   District_Administrator     NaN         NaN           18400
# 1   District_Administrator     NaN         NaN           18401
# 2   District_Administrator     NaN         NaN           18402
# 3     School_Administrator     NaN         NaN           18403
# 4     School_Administrator     NaN         NaN           18404
# ..                     ...     ...         ...             ...
# 68                 Student  female  2016-09-30           18469
# 69                 Student    male  2016-11-12           18470
# 70                 Student  female  2016-02-15           18471
# 71                 Student    male  2016-04-27           18472
# 72                 Student    male  2016-06-10           18473
#
#                   school_name  grade             class_1 class_2 class_3  \
# 0                         NaN    NaN                 NaN     NaN     NaN
# 1                         NaN    NaN                 NaN     NaN     NaN
# 2                         NaN    NaN                 NaN     NaN     NaN
# 3         Bayside High School    NaN                 NaN     NaN     NaN
# 4       Bayside Middle School    NaN                 NaN     NaN     NaN
# ..                        ...    ...                 ...     ...     ...
# 68  Bayside Elementary School    3.0  Grade 03 - Depaolo     NaN     NaN
# 69  Bayside Elementary School    3.0  Grade 03 - Depaolo     NaN     NaN
# 70  Bayside Elementary School    3.0  Grade 03 - Depaolo     NaN     NaN
# 71  Bayside Elementary School    3.0  Grade 03 - Depaolo     NaN     NaN
# 72  Bayside Elementary School    3.0  Grade 03 - Depaolo     NaN     NaN
#
#    class_4
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 68     NaN
# 69     NaN
# 70     NaN
# 71     NaN
# 72     NaN
#
# [73 rows x 14 columns]

# %%
schools = pd.DataFrame(df["school_name"].unique())
schools = schools.dropna(how="any")
schools.insert(0, 'id', range(0, 0 + len(schools)))
schools = schools.rename(columns={0:"school_name"})
schools.to_csv("schools.csv", index=False)
schools
# Out:
#    id                school_name
# 1   0        Bayside High School
# 2   1      Bayside Middle School
# 3   2  Bayside Elementary School

# %%
classes = []
for c in class_columns:
    for cl in df[c].unique():
        classes.append(cl)

classes = pd.DataFrame(classes)
classes = classes.dropna(how='any')
classes = classes.drop_duplicates()
classes = classes.rename(columns={0:"class_name"})
classes.insert(0, 'id', range(2000, 2000 + len(classes)))
classes.to_csv("classes.csv", index=False)
classes
# Out:
#      id          class_name
# 1  2000            MATH-11A
# 2  2001             ELA-11B
# 3  2002             ART-11C
# 4  2003         SCIENCE-11C
# 5  2004          SPANISH-6A
# 6  2005          HISTORY-6D
# 7  2006          THEATRE-6A
# 8  2007  Grade 03 - Depaolo

# %%
def convert_to_id(type, name, data):
    if pd.isnull(name):
        return 
    s = data.set_index(type)['id']
    return s[name]

result = convert_to_id("class_name", "THEATRE-6A", classes)
result
# Out:
# 2006

# %% [markdown]
# ### Convert dataframe values to id counterparts

# %%
df['school_name'] = df.apply(lambda x: convert_to_id('school_name', x['school_name'], schools),axis=1)
df = df.rename(columns={'school_name': 'school_id'})

df['role'] = df.apply(lambda x: format_fix(x['role'], roles),axis=1)
df.insert(0, 'id', range(0, 0 + len(df)))

for c in class_columns:
    df[c] = df.apply(lambda x: convert_to_id('class_name', x[c], classes),axis=1)

# %% [markdown]
# ### Create class array column

# %%
class_array = df[(list(df.filter(regex='class')))]
class_array = class_array.values
class_array

clean_class_arrays = []
for array in class_array:
    array = array[~np.isnan(array)]
    clean_class_arrays.append(array)

df["classes"] = clean_class_arrays
df
# Out:
#     id first_name   last_name    password                    email  \
# 0    0        Sam     Bobrick   org_admin     Bobrick@bayside.demo
# 1    1    Michael      Poryes   org_admin      Poryes@bayside.demo
# 2    2      Susan     Sherman   org_admin     Sherman@bayside.demo
# 3    3    Richard     Belding  site_admin     Belding@bayside.demo
# 4    4     Wesley      Lawler  site_admin      Lawler@bayside.demo
# ..  ..        ...         ...         ...                      ...
# 68  68    Larissa       Swing     student       Swing@bayside.demo
# 69  69   Augustin  Carbonelle     student  Carbonelle@bayside.demo
# 70  70     Vivian        Shah     student        Shah@bayside.demo
# 71  71      David    Langhoff     student    Langhoff@bayside.demo
# 72  72     Declan     Brennan     student     Brennan@bayside.demo
#
#                       role  gender   birthdate  user_school_id  school_id  \
# 0   district-administrator     NaN         NaN           18400        NaN
# 1   district-administrator     NaN         NaN           18401        NaN
# 2   district-administrator     NaN         NaN           18402        NaN
# 3            administrator     NaN         NaN           18403        0.0
# 4            administrator     NaN         NaN           18404        1.0
# ..                     ...     ...         ...             ...        ...
# 68                 student  female  2016-09-30           18469        2.0
# 69                 student    male  2016-11-12           18470        2.0
# 70                 student  female  2016-02-15           18471        2.0
# 71                 student    male  2016-04-27           18472        2.0
# 72                 student    male  2016-06-10           18473        2.0
#
#     grade  class_1  class_2  class_3  class_4   classes
# 0     NaN      NaN      NaN      NaN      NaN        []
# 1     NaN      NaN      NaN      NaN      NaN        []
# 2     NaN      NaN      NaN      NaN      NaN        []
# 3     NaN      NaN      NaN      NaN      NaN        []
# 4     NaN      NaN      NaN      NaN      NaN        []
# ..    ...      ...      ...      ...      ...       ...
# 68    3.0   2007.0      NaN      NaN      NaN  [2007.0]
# 69    3.0   2007.0      NaN      NaN      NaN  [2007.0]
# 70    3.0   2007.0      NaN      NaN      NaN  [2007.0]
# 71    3.0   2007.0      NaN      NaN      NaN  [2007.0]
# 72    3.0   2007.0      NaN      NaN      NaN  [2007.0]
#
# [73 rows x 16 columns]

# %%
def get_enrollments(user_enrollments, user_id, classes):
    for c in classes:
        user_enrollments.append([user_id, c])
    
    return user_enrollments

# %%
enrollment_data = df[["id", "classes"]]
enrollments = []

enrollment_data.apply(lambda x: get_enrollments(enrollments, x['id'], x["classes"]),axis=1)

enrollments = pd.DataFrame(enrollments)
enrollments = enrollments.rename(columns={0: "person_id", 1: "class_id"})
enrollments.insert(0, 'id', range(5000, 5000 + len(enrollments)))
enrollments.to_csv("enrollments.csv", index=False)
enrollments
# Out:
#        id  person_id  class_id
# 0    5000          6    2000.0
# 1    5001          7    2001.0
# 2    5002          8    2002.0
# 3    5003          9    2003.0
# 4    5004         10    2000.0
# ..    ...        ...       ...
# 171  5171         68    2007.0
# 172  5172         69    2007.0
# 173  5173         70    2007.0
# 174  5174         71    2007.0
# 175  5175         72    2007.0
#
# [176 rows x 3 columns]

# %%
users = df.drop(columns=(list(df.filter(regex='class'))))
users.to_csv("users.csv", index=False)
users
# Out:
#     id first_name   last_name    password                    email  \
# 0    0        Sam     Bobrick   org_admin     Bobrick@bayside.demo
# 1    1    Michael      Poryes   org_admin      Poryes@bayside.demo
# 2    2      Susan     Sherman   org_admin     Sherman@bayside.demo
# 3    3    Richard     Belding  site_admin     Belding@bayside.demo
# 4    4     Wesley      Lawler  site_admin      Lawler@bayside.demo
# ..  ..        ...         ...         ...                      ...
# 68  68    Larissa       Swing     student       Swing@bayside.demo
# 69  69   Augustin  Carbonelle     student  Carbonelle@bayside.demo
# 70  70     Vivian        Shah     student        Shah@bayside.demo
# 71  71      David    Langhoff     student    Langhoff@bayside.demo
# 72  72     Declan     Brennan     student     Brennan@bayside.demo
#
#                       role  gender   birthdate  user_school_id  school_id  \
# 0   district-administrator     NaN         NaN           18400        NaN
# 1   district-administrator     NaN         NaN           18401        NaN
# 2   district-administrator     NaN         NaN           18402        NaN
# 3            administrator     NaN         NaN           18403        0.0
# 4            administrator     NaN         NaN           18404        1.0
# ..                     ...     ...         ...             ...        ...
# 68                 student  female  2016-09-30           18469        2.0
# 69                 student    male  2016-11-12           18470        2.0
# 70                 student  female  2016-02-15           18471        2.0
# 71                 student    male  2016-04-27           18472        2.0
# 72                 student    male  2016-06-10           18473        2.0
#
#     grade
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 68    3.0
# 69    3.0
# 70    3.0
# 71    3.0
# 72    3.0
#
# [73 rows x 11 columns]
